# %% [markdown]
# ## Utilice el método de Euler para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.
# ![](tarea12.1.png)

# %% [markdown]
# ### a)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
def euler_method(f, t0, y0, h, t_end):
    t_values = [t0]
    y_values = [y0]
    t = t0
    y = y0
    while t < t_end:
        y = y + h * f(t, y)
        t = round(t + h, 10)  
        t_values.append(t)
        y_values.append(y)
    return t_values, y_values
def f1(t, y):
    return y / t - (y / t) ** 2
t0, y0, h, t_end = 1, 1, 0.1, 2
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t_vals, y_vals, '-s', label='aproximacion')
plt.show()
# Out:
#       t         y
# 0   1.0  1.000000
# 1   1.1  1.000000
# 2   1.2  1.008264
# 3   1.3  1.021689
# 4   1.4  1.038515
# 5   1.5  1.057668
# 6   1.6  1.078461
# 7   1.7  1.100432
# 8   1.8  1.123262
# 9   1.9  1.146724
# 10  2.0  1.170652

# %% [markdown]
# ### b)

# %%
def f1(t, y):
    return 1 + y/t + (y/t)**2 
t0, y0, h, t_end = 1,0,0.2,3
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t_vals, y_vals, '-s', label='aproximacion')
plt.show()
# Out:
#       t         y
# 0   1.0  0.000000
# 1   1.2  0.200000
# 2   1.4  0.438889
# 3   1.6  0.721243
# 4   1.8  1.052038
# 5   2.0  1.437251
# 6   2.2  1.884261
# 7   2.4  2.402270
# 8   2.6  3.002837
# 9   2.8  3.700601
# 10  3.0  4.514277

# %% [markdown]
# ### c)

# %%
def f1(t, y):
    return -(y+1)*(y+3)
t0, y0, h, t_end = 0,-2,0.2,2
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t_vals, y_vals, '-s', label='aproximacion')
plt.show()
# Out:
#       t         y
# 0   0.0 -2.000000
# 1   0.2 -1.800000
# 2   0.4 -1.608000
# 3   0.6 -1.438733
# 4   0.8 -1.301737
# 5   1.0 -1.199251
# 6   1.2 -1.127491
# 7   1.4 -1.079745
# 8   1.6 -1.049119
# 9   1.8 -1.029954
# 10  2.0 -1.018152

# %% [markdown]
# ### d)

# %%
def f1(t, y):
    return -5*y + 5*t**2+2*t
t0, y0, h, t_end = 0,1/3,0.1,1
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t_vals, y_vals, '-s', label='aproximacion')
plt.show()
# Out:
#       t         y
# 0   0.0  0.333333
# 1   0.1  0.166667
# 2   0.2  0.108333
# 3   0.3  0.114167
# 4   0.4  0.162083
# 5   0.5  0.241042
# 6   0.6  0.345521
# 7   0.7  0.472760
# 8   0.8  0.621380
# 9   0.9  0.790690
# 10  1.0  0.980345

# %% [markdown]
# ## Aquí se dan las soluciones reales para los problemas de valor inicial en el ejercicio 3. calcule el error real en las aproximaciones del ejercicio 3.
# ![](tarea12.2.png)

# %% [markdown]
# ### a)

# %%
def f1(t, y):
    return y / t - (y / t) ** 2
def exacto(t):
    return t / (1 + np.log(t))
t0, y0, h, t_end = 1, 1, 0.1, 2
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
df["Exacto y"] = df["t"].apply(exacto)
df["Error"] = abs(df["y"] - df["Exacto y"])
print(df)
plt.plot(t_vals, y_vals,'-s',label='Aproximacion',color='Blue')
plt.plot(t_vals, exacto(t_vals),'-s',label='Real',color='Red')
plt.legend(loc='upper left')
plt.show()
# Out:
#       t         y  Exacto y     Error
# 0   1.0  1.000000  1.000000  0.000000
# 1   1.1  1.000000  1.004282  0.004282
# 2   1.2  1.008264  1.014952  0.006688
# 3   1.3  1.021689  1.029814  0.008124
# 4   1.4  1.038515  1.047534  0.009019
# 5   1.5  1.057668  1.067262  0.009594
# 6   1.6  1.078461  1.088433  0.009972
# 7   1.7  1.100432  1.110655  0.010223
# 8   1.8  1.123262  1.133654  0.010392
# 9   1.9  1.146724  1.157228  0.010505
# 10  2.0  1.170652  1.181232  0.010581

# %% [markdown]
# ### b)

# %%
def f1(t, y):
    return 1 + y/t + (y/t)**2
def exacto(t):
    return t* np.tan(np.log(t))
t0, y0, h, t_end = 1, 0,0.2,3
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
df["Exacto y"] = df["t"].apply(exacto)
df["Error"] = abs(df["y"] - df["Exacto y"])
print(df)
plt.plot(t_vals, y_vals,'-s',label='Aproximacion',color='Blue')
plt.plot(t_vals, exacto(t_vals),'-s',label='Real',color='Red')
plt.legend(loc='upper left')
plt.show()
# Out:
#       t         y  Exacto y     Error
# 0   1.0  0.000000  0.000000  0.000000
# 1   1.2  0.200000  0.221243  0.021243
# 2   1.4  0.438889  0.489682  0.050793
# 3   1.6  0.721243  0.812753  0.091510
# 4   1.8  1.052038  1.199439  0.147401
# 5   2.0  1.437251  1.661282  0.224031
# 6   2.2  1.884261  2.213502  0.329241
# 7   2.4  2.402270  2.876551  0.474282
# 8   2.6  3.002837  3.678475  0.675638
# 9   2.8  3.700601  4.658665  0.958064
# 10  3.0  4.514277  5.874100  1.359823

# %% [markdown]
# ### c)

# %%
def f3(t, y):
    return -(y + 1) * (y + 3)
def exact_solution_c(t):
    return -3 + 2 / (1 + np.exp(-2 * t))
t0, y0, h, t_end = 0, -2, 0.2, 2
t_vals, y_vals = euler_method(f3, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
df["Exacto y"] = df["t"].apply(exact_solution_c)
df["Error"] = abs(df["y"] - df["Exacto y"])
print(df)
plt.plot(df["t"], df["y"], '-s', label='Aproximación', color='blue')
plt.plot(df["t"], df["Exacto y"], '-o', label='Real', color='red')
plt.xlabel("t")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()
# Out:
#       t         y  Exacto y     Error
# 0   0.0 -2.000000 -2.000000  0.000000
# 1   0.2 -1.800000 -1.802625  0.002625
# 2   0.4 -1.608000 -1.620051  0.012051
# 3   0.6 -1.438733 -1.462950  0.024218
# 4   0.8 -1.301737 -1.335963  0.034226
# 5   1.0 -1.199251 -1.238406  0.039155
# 6   1.2 -1.127491 -1.166345  0.038854
# 7   1.4 -1.079745 -1.114648  0.034903
# 8   1.6 -1.049119 -1.078331  0.029212
# 9   1.8 -1.029954 -1.053194  0.023240
# 10  2.0 -1.018152 -1.035972  0.017821

# %% [markdown]
# ### d)

# %%
def f1(t, y):
    return -5 * y + 5 * t ** 2 + 2 * t
def exacto(t):
   return t ** 2 + (1 / 3) * np.exp(-5 * t)
t0, y0, h, t_end = 0, 1/3, 0.1, 1
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
df["Exacto y"] = df["t"].apply(exacto)
df["Error"] = abs(df["y"] - df["Exacto y"])
print(df)
plt.plot(df["t"], df["y"], '-s', label='Aproximación', color='blue')
plt.plot(df["t"], df["Exacto y"], '-o', label='Real', color='red')
plt.xlabel("t")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()
# Out:
#       t         y  Exacto y     Error
# 0   0.0  0.333333  0.333333  0.000000
# 1   0.1  0.166667  0.212177  0.045510
# 2   0.2  0.108333  0.162626  0.054293
# 3   0.3  0.114167  0.164377  0.050210
# 4   0.4  0.162083  0.205112  0.043028
# 5   0.5  0.241042  0.277362  0.036320
# 6   0.6  0.345521  0.376596  0.031075
# 7   0.7  0.472760  0.500066  0.027305
# 8   0.8  0.621380  0.646105  0.024725
# 9   0.9  0.790690  0.813703  0.023013
# 10  1.0  0.980345  1.002246  0.021901

# %% [markdown]
# ##  Utilice los resultados del ejercicio 3 y la interpolación lineal para aproximar los siguientes valores de y(t). Compare las aproximaciones asignadas para los valores reales obtenidos mediante las funciones determinadas en el ejercicio.
# ![](tarea12.3.png)

# %% [markdown]
# ### a)

# %%
from scipy.interpolate import CubicSpline
def f1(t, y):
    return y / t - (y / t) ** 2
def exacto(t):
    return t / (1 + np.log(t))
t0, y0, h, t_end = 1, 1, 0.1, 2
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
spline = CubicSpline(t_vals, y_vals)
t=np.linspace(t0, t_end, 100)
y=spline(t)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t,exacto(t),label='Real',color='red')
plt.plot(t, y,label='Spline cubico',color='Blue')
plt.legend(loc='upper left')
plt.show()
print ('El valor real de 0.25 es :', exacto(0.25),'mientras que el valor determinado con splines es:',spline(0.25) )
print ('El valor real de 0.93 es :', exacto(0.93),'mientras que el valor determinado con splines es:',spline(0.93) )
# Out:
#       t         y
# 0   1.0  1.000000
# 1   1.1  1.000000
# 2   1.2  1.008264
# 3   1.3  1.021689
# 4   1.4  1.038515
# 5   1.5  1.057668
# 6   1.6  1.078461
# 7   1.7  1.100432
# 8   1.8  1.123262
# 9   1.9  1.146724
# 10  2.0  1.170652
# El valor real de 0.25 es : -0.6471748623905226 mientras que el valor determinado con splines es: 1.608726427863775
# El valor real de 0.93 es : 1.0027718477462106 mientras que el valor determinado con splines es: 1.0067492451045537

# %% [markdown]
# ### b)

# %%
def f1(t, y):
    return 1+y/t+(y/t)**2
def exacto(t):
    return t*np.tan(np.log(t))
t0, y0, h, t_end = 1, 0,0.2,3
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
spline = CubicSpline(t_vals, y_vals)
t=np.linspace(t0, t_end, 100)
y=spline(t)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t,exacto(t),label='Real',color='red')
plt.plot(t, y,label='Spline cubico',color='Blue')
plt.legend(loc='upper left')
plt.show()
print ('El valor real de 1.25 es :', exacto(1.25),'mientras que el valor determinado con splines es:',spline(2.25) )
print ('El valor real de 1.93 es :', exacto(1.93),'mientras que el valor determinado con splines es:',spline(1.93) )
# Out:
#       t         y
# 0   1.0  0.000000
# 1   1.2  0.200000
# 2   1.4  0.438889
# 3   1.6  0.721243
# 4   1.8  1.052038
# 5   2.0  1.437251
# 6   2.2  1.884261
# 7   2.4  2.402270
# 8   2.6  3.002837
# 9   2.8  3.700601
# 10  3.0  4.514277
# El valor real de 1.25 es : 0.2836531261952289 mientras que el valor determinado con splines es: 2.0066946411581505
# El valor real de 1.93 es : 1.4902277738186658 mientras que el valor determinado con splines es: 1.2958053322196763

# %% [markdown]
# ### c)

# %%
def f1(t, y):
    return -(y+1)*(y+3)
def exacto(t):
    return -3+2/(1+np.exp(-2*t))
t0, y0, h, t_end = 0, -2, 0.2, 2
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
spline = CubicSpline(t_vals, y_vals)
t=np.linspace(t0, t_end, 100)
y=spline(t)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t,exacto(t),label='Real',color='red')
plt.plot(t, y,label='Spline cubico',color='Blue')
plt.legend(loc='upper left')
plt.show()
print ('El valor real de 2.10 es :', exacto(2.10),'mientras que el valor determinado con splines es:',spline(2.10) )
print ('El valor real de 1.93 es :', exacto(2.75),'mientras que el valor determinado con splines es:',spline(2.75) )
# Out:
#       t         y
# 0   0.0 -2.000000
# 1   0.2 -1.800000
# 2   0.4 -1.608000
# 3   0.6 -1.438733
# 4   0.8 -1.301737
# 5   1.0 -1.199251
# 6   1.2 -1.127491
# 7   1.4 -1.079745
# 8   1.6 -1.049119
# 9   1.8 -1.029954
# 10  2.0 -1.018152
# El valor real de 2.10 es : -1.0295480633865461 mientras que el valor determinado con splines es: -1.0138357255475137
# El valor real de 1.93 es : -1.008140275431792 mientras que el valor determinado con splines es: -0.9752230847379707

# %% [markdown]
# ### d)

# %%
def f1(t, y):
    return -5*y+5*t**2+2*t
def exacto(t):
    return t**2+1/3*np.exp(-5*t)
t0, y0, h, t_end = 0, 1/3, 0.1, 1
t_vals, y_vals = euler_method(f1, t0, y0, h, t_end)
spline = CubicSpline(t_vals, y_vals)
t=np.linspace(t0, t_end, 100)
y=spline(t)
df = pd.DataFrame({"t": t_vals, "y": y_vals})
print(df)
plt.plot(t,exacto(t),label='Real',color='red')
plt.plot(t, y,label='Spline cubico',color='Blue')
plt.legend(loc='upper left')
plt.show()
print ('El valor real de 0.54 es :', exacto(0.54),'mientras que el valor determinado con splines es:',spline(0.54) )
print ('El valor real de 0.94 es :', exacto(0.94),'mientras que el valor determinado con splines es:',spline(0.94) )
# Out:
#       t         y
# 0   0.0  0.333333
# 1   0.1  0.166667
# 2   0.2  0.108333
# 3   0.3  0.114167
# 4   0.4  0.162083
# 5   0.5  0.241042
# 6   0.6  0.345521
# 7   0.7  0.472760
# 8   0.8  0.621380
# 9   0.9  0.790690
# 10  1.0  0.980345
# El valor real de 0.54 es : 0.3140018375799166 mientras que el valor determinado con splines es: 0.27996279078742486
# El valor real de 0.94 es : 0.8866317590338986 mientras que el valor determinado con splines es: 0.8641265939446413
